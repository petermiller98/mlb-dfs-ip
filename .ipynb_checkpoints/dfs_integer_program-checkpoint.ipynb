# %% [markdown]
# # Daily Fantasy Baseball Integer Program

# %%
import numpy as np
import pandas as pd
from pulp import *
# Out:
# Using license file /Users/petermiller/gurobi.lic
# Academic license - for non-commercial use only
# No parameters matching '_test' found

# %% [markdown]
# ### Data Cleaning Functions

# %%
def read_players(path_to_pitchers, path_to_hitters):
    """Clean and combine PATH_TO_PITCHERS and PATH_TO_HITTERS 
        tables from Daily Fantasy Nerd"""
    pitchers = pd.read_csv(path_to_pitchers)
    pitchers = pitchers[['Player Name', 'Pos', 'Salary',
                         'Team', 'Opp', 'Batting Order (Confirmed)', 'Proj FP']]
    hitters = pd.read_csv(path_to_hitters)
    hitters = hitters[['Player Name', 'Pos', 'Salary',
                       'Team', 'Opp', 'Proj FP']]
    pitchers = pitchers.rename(columns={'Player Name': 'Name',
                                            'Pos' : 'Position'})
    hitters = hitters.rename(columns={'Player Name': 'Name',
                                            'Pos' : 'Position'})
    data = pd.concat([pitchers, hitters])
    data['Opp'] = data['Opp'].str.replace('@', '')
    return data

# %%
def remove_players(data, names):
    """Remove players in list NAMES from DF"""
    data = data.copy(deep=True)
    for name in names:
        data = data[data['Name'] != name]
    data = data.reset_index()
    data = data.drop('index', axis=1)
    return data

# %%
def encode_position(data):
    """One Hot Encode Position from DATA
        and add columns to DATA"""
    data = data.copy(deep=True)
    P = np.zeros(data.shape[0], dtype=int)
    B1 = np.zeros(data.shape[0], dtype=int)
    B2 = np.zeros(data.shape[0], dtype=int)
    B3 = np.zeros(data.shape[0], dtype=int)
    C = np.zeros(data.shape[0], dtype=int)
    SS = np.zeros(data.shape[0], dtype=int)
    OF = np.zeros(data.shape[0], dtype=int)
    
    for i in range(data.shape[0]):
        if data.iloc[i, 1].find('SP') != -1:
            np.put(P, i, 1) 
        if data.iloc[i, 1].find('RP') != -1:
            np.put(P, i, 1)
        if data.iloc[i, 1].find('1B') != -1:
            np.put(B1, i, 1)
        if data.iloc[i, 1].find('2B') != -1:
            np.put(B2, i, 1)
        if data.iloc[i, 1].find('3B') != -1:
            np.put(B3, i, 1)
        if data.iloc[i, 1].find('C') != -1:
            np.put(C, i, 1)
        if data.iloc[i, 1].find('SS') != -1:
            np.put(SS, i, 1)
        if data.iloc[i, 1].find('OF') != -1:
            np.put(OF, i, 1)
    
    data['P'] = P
    data['1B'] = B1
    data['2B'] = B2
    data['3B'] = B3
    data['C'] = C
    data['SS'] = SS
    data['OF'] = OF
    return data

# %%
def encode_team(data):
    """One Hot Encodes Team column in DATA"""
    data = data.copy(deep=True)
    one_hot1 = pd.get_dummies(data['Team'], prefix='Team')
    data = pd.concat([data, one_hot1], axis= 1).reindex(data.index)
    one_hot2 = pd.get_dummies(data['Opp'], prefix='Opp')
    data = pd.concat([data, one_hot2], axis= 1).reindex(data.index)
    return data

# %% [markdown]
# ### Integer Program Functions

# %%
def prepare_arguments(data, old_lineups):
    """Returns list of dictionaries that are arguments for generate_lineups"""
    player = [str(i) for i in range(data.shape[0])]
    point = {str(i): data['Proj FP'][i] for i in range(data.shape[0])} 
    cost = {str(i): data['Salary'][i] for i in range(data.shape[0])}
    P = {str(i): data['P'][i] for i in range(data.shape[0])}
    B1 = {str(i): data['1B'][i] for i in range(data.shape[0])}
    B2 = {str(i): data['2B'][i] for i in range(data.shape[0])}
    B3 = {str(i): data['3B'][i] for i in range(data.shape[0])}
    C = {str(i): data['C'][i] for i in range(data.shape[0])}
    SS = {str(i): data['SS'][i] for i in range(data.shape[0])}
    OF = {str(i): data['OF'][i] for i in range(data.shape[0])}
    return [player, point, cost, P, B1, B2, B3, C, SS, OF, old_lineups]

# %%
def create_lineup(data, player, point, cost, P, B1, B2, B3, C, SS, OF, old_lineups):
    """Returns list of names of optimal lineup given constraints."""
    # Problem Instantiation
    prob = LpProblem("DFS_Baseball", LpMaximize)
    player_vars = LpVariable.dicts("Players",player,0,1,LpBinary)
    
    # Postion/Cost/Overlap Constraints
    prob += lpSum([point[i] * player_vars[i] for i in player]), "Points"
    prob += lpSum([player_vars[i] for i in player]) == 10, "10_Players"
    prob += lpSum([cost[i] * player_vars[i] for i in player]) <= 50000, "Total_Cost"
    prob += lpSum([P[i] * player_vars[i] for i in player]) == 2, "2Pitchers"
    prob += lpSum([B1[i] * player_vars[i] for i in player]) == 1, "1B"
    prob += lpSum([B2[i] * player_vars[i] for i in player]) == 1, "2B"
    prob += lpSum([B3[i] * player_vars[i] for i in player]) == 1, "3B"
    prob += lpSum([C[i] * player_vars[i] for i in player]) == 1, "C"
    prob += lpSum([SS[i] * player_vars[i] for i in player]) == 1, "SS"
    prob += lpSum([OF[i] * player_vars[i] for i in player]) == 3, "OF"
    prob += lpSum([old_lineups.get(str(i)) * player_vars.get(str(i)) for i in range(data.shape[0])]) <= 5, "Overlap"
    teams = list(data['Team'].unique())
    num_teams = len(teams)
    
    # Must pick 4 players from same team
    used_4_in_team = [LpVariable("u{}".format(i + 1), cat="Binary") for i in range(num_teams)]
    i = 0
    for team in teams:
        prob += (4 * used_4_in_team[i] <= 
             lpSum(data['Team_' + team][k] * player_vars.get(str(k)) for k in range(data.shape[0])))
        i += 1
    prob += lpSum(used_4_in_team) >= 1
    
    # No pitcher vs batter constraint
    for team in teams:
        prob += ((8 * lpSum(P.get(str(k)) * player_vars.get(str(k)) * data['Team_' + team][k] for k in range(data.shape[0])) +
            lpSum((1 - P.get(str(k))) * player_vars.get(str(k)) * data['Opp_' + team][k] for k in range(data.shape[0])) <= 8))
    
    # Stacking Constraint
    
    
    
    status = prob.solve()
    selection = {}
    for v in prob.variables():
        if len(v.name.split("_")) == 2:
            index = int(v.name.split("_")[1])
            selection[index] = v.varValue
    data['integer_programming'] = 0.0
    for i in selection:
        data.loc[i, 'integer_programming'] = selection[i]
    lineup = data[data['integer_programming'] == 1.0]
    indexes = list(data.index[data['integer_programming'] == 1.0])
    for idx in indexes:
        old_lineups[str(idx)] = 1
    lineup = data[data['integer_programming'] == 1.0]
    total_points = lineup['Proj FP'].sum()
    total_cost = lineup['Salary'].sum()
    total_players = lineup.shape[0]
    print("Total points: {}\nCost: ${}\nNumber of players: {}".format(total_points, total_cost, total_players))
    return [lineup['Name'], old_lineups]

# %%
def create_multiple_lineups(data, num_lineups):
    """Prints NUM_LINEUPS lineups given DATA"""
    old_lineups = {str(i): 0 for i in range(data.shape[0])}
    for j in range(num_lineups):
        dicts = prepare_arguments(data, old_lineups)
        optimal_lineup, old_lineups = create_lineup(data, dicts[0], dicts[1], dicts[2], 
                     dicts[3], dicts[4], dicts[5], 
                     dicts[6], dicts[7], dicts[8], dicts[9], dicts[10])
        print('Lineup ' + str(j + 1) + ': ')
        print('\n')
        for name in optimal_lineup:
            print(name + " ")
        print('\n')

# %%
def optimize_multiple_lineups(path_to_pitchers, path_to_hitters, removal_list, num_lineups):
    players_table = read_players(path_to_pitchers, path_to_hitters)
    players_table = remove_players(players_table, removal_list)
    players_table = encode_position(players_table)
    players_table = encode_team(players_table)
    create_multiple_lineups(players_table, num_lineups)

# %% [markdown]
# ### edit paths, names in removal list, number of lineups -> run

# %%
path_to_pitchers = 'DFN_Pitchers_08032020.csv'
path_to_hitters = 'DFN_Hitters_08032020.csv'

removal_list = ['Adalberto Mondesi', 'Corey Seager', 'Manny Pina',
                'Ozzie Albies', 'Kyle Holder', 'Hunter Dozier',
                'Nick Gordon', 'Daniel Descalso', 'Mookie Betts', 
                'Kyle Isbel', 'Jeison Guzman', 'Pete Kozma',
                'Drew Waters', 'Luke Voit', 'Zach McKinstry', 
                'Bubba Starling', 'Gleyber Torres', 'Tyler Flowers',
                'Jorge Polanco', 'Adam Frazier', 'Sam Haggerty',
                'Kelvin Gutierrez', 'Brett Anderson', 'Bobby Witt Jr.',
                'Roman Quinn','Eddie Rosario']

optimize_multiple_lineups(path_to_pitchers, path_to_hitters, removal_list, 50)
# Out:
# Total points: 113.9
# Cost: $49900
# Number of players: 10
# Lineup 1:
#
#
# Gerrit Cole
# Frankie Montas
# Alex Dickerson
# Nelson Cruz
# Yoan Moncada
# Jose Abreu
# Luis Robert
# Kevin Newman
# Jacob Stallings
# Nick Madrigal
#
#
# Total points: 113.8
# Cost: $49700
# Number of players: 10
# Lineup 2:
#
#
# Gerrit Cole
# Chris Paddack
# Evan Longoria
# Nelson Cruz
# Mitch Garver
# Jose Abreu
# Luis Robert
# J.P. Crawford
# Adam Engel
# Nick Madrigal
#
#
# Total points: 111.9
# Cost: $50000
# Number of players: 10
# Lineup 3:
#
#
# Chris Paddack
# Frankie Montas
# Mike Yastrzemski
# Alex Dickerson
# Evan Longoria
# Brandon Belt
# Luis Robert
# James McCann
# Robinson Cano
# Didi Gregorius
#
#
# Total points: 110.60000000000001
# Cost: $50000
# Number of players: 10
# Lineup 4:
#
#
# Gerrit Cole
# Frankie Montas
# Trevor Story
# Jeff McNeil
# Jose Abreu
# Eloy Jimenez
# Brandon Nimmo
# James McCann
# Nick Madrigal
# Steven Souza Jr.
#
#
# Total points: 108.9
# Cost: $49900
# Number of players: 10
# Lineup 5:
#
#
# Gerrit Cole
# Lewis Thorpe
# Nolan Arenado
# Nelson Cruz
# Mitch Garver
# Edwin Encarnacion
# J.P. Crawford
# Byron Buxton
# Nick Madrigal
# Jose Marmolejos
#
#
# Total points: 108.69999999999999
# Cost: $50000
# Number of players: 10
# Lineup 6:
#
#
# Gerrit Cole
# Frankie Montas
# Matt Chapman
# Nelson Cruz
# Mitch Garver
# Brandon Crawford
# Khris Davis
# Stephen Piscotty
# Ryan O'Hearn
# Nick Madrigal
#
#
# Total points: 107.5
# Cost: $50000
# Number of players: 10
# Lineup 7:
#
#
# Gerrit Cole
# Danny Duffy
# Alex Dickerson
# Nelson Cruz
# Mitch Garver
# Kyle Seager
# Shed Long Jr.
# Matt Kemp
# J.P. Crawford
# Evan White
#
#
# Total points: 106.50000000000001
# Cost: $50000
# Number of players: 10
# Lineup 8:
#
#
# Gerrit Cole
# Justus Sheffield
# Evan Longoria
# Brandon Belt
# Aaron Hicks
# Mitch Garver
# DJ LeMahieu
# Brett Gardner
# J.P. Crawford
# Ben Gamel
#
#
# Total points: 106.1
# Cost: $50000
# Number of players: 10
# Lineup 9:
#
#
# Gerrit Cole
# Johnny Cueto
# Alex Dickerson
# Evan Longoria
# Javier Baez
# Brandon Belt
# Willson Contreras
# Joc Pederson
# Robinson Cano
# Albert Almora Jr.
#
#
# Total points: 104.9
# Cost: $50000
# Number of players: 10
# Lineup 10:
#
#
# Gerrit Cole
# Carlos Rodon
# David Dahl
# Michael Conforto
# Jose Abreu
# Gio Urshela
# Luis Robert
# J.P. Crawford
# Wilson Ramos
# Nick Madrigal
#
#
# Total points: 104.9
# Cost: $49900
# Number of players: 10
# Lineup 11:
#
#
# Gerrit Cole
# Frankie Montas
# Alex Dickerson
# Tyler Heineman
# Evan Longoria
# Steven Duggar
# Matt Adams
# Alex Gordon
# Nick Madrigal
# Orlando Arcia
#
#
# Total points: 104.7
# Cost: $50000
# Number of players: 10
# Lineup 12:
#
#
# Jacob deGrom
# Frankie Montas
# Alex Dickerson
# Evan Longoria
# Luis Robert
# Rhys Hoskins
# Will Smith
# Scott Kingery
# Didi Gregorius
# Jay Bruce
#
#
# Total points: 103.4
# Cost: $49800
# Number of players: 10
# Lineup 13:
#
#
# Gerrit Cole
# Chris Paddack
# Fernando Tatis Jr.
# Nelson Cruz
# Daniel Murphy
# Manny Machado
# Mitch Garver
# Dylan Moore
# Nick Madrigal
# Edward Olivares
#
#
# Total points: 102.4
# Cost: $50000
# Number of players: 10
# Lineup 14:
#
#
# Gerrit Cole
# Jake Arrieta
# Marcus Semien
# Cody Bellinger
# Yoan Moncada
# Jose Abreu
# Salvador Perez
# Luis Robert
# Tyrone Taylor
# Nick Madrigal
#
#
# Total points: 101.6
# Cost: $50000
# Number of players: 10
# Lineup 15:
#
#
# Gerrit Cole
# Derek Holland
# Evan Longoria
# Josh Bell
# Sam Hilliard
# Luis Robert
# Tony Wolters
# Bryan Reynolds
# Kevin Newman
# Robinson Cano
#
#
# Total points: 101.10000000000001
# Cost: $49800
# Number of players: 10
# Lineup 16:
#
#
# Walker Buehler
# Frankie Montas
# Bryce Harper
# J.T. Realmuto
# Justin Turner
# Jose Abreu
# Andrew McCutchen
# Luis Robert
# Didi Gregorius
# Nick Madrigal
#
#
# Total points: 100.00000000000001
# Cost: $49900
# Number of players: 10
# Lineup 17:
#
#
# Gerrit Cole
# Justus Sheffield
# Evan Longoria
# Miguel Sano
# Mitch Garver
# Jorge Soler
# Jurickson Profar
# Kyle Lewis
# J.P. Crawford
# Mallex Smith
#
#
# Total points: 98.1
# Cost: $50000
# Number of players: 10
# Lineup 18:
#
#
# Gerrit Cole
# Frankie Montas
# Keston Hiura
# Avisail Garcia
# Maikel Franco
# Justin Smoak
# Luis Robert
# James McCann
# Ender Inciarte
# Orlando Arcia
#
#
# Total points: 97.0
# Cost: $50000
# Number of players: 10
# Lineup 19:
#
#
# Gerrit Cole
# Frankie Montas
# Aaron Judge
# Pete Alonso
# Gary Sanchez
# Gio Urshela
# Kevin Newman
# Jason Heyward
# Franchy Cordero
# Nick Madrigal
#
#
# Total points: 96.80000000000001
# Cost: $50000
# Number of players: 10
# Lineup 20:
#
#
# Chris Paddack
# Frankie Montas
# Ramon Laureano
# Freddie Freeman
# Evan Longoria
# Mark Canha
# Trent Grisham
# Sean Murphy
# Kevin Newman
# Nick Madrigal
#
#
# Total points: 95.60000000000001
# Cost: $49900
# Number of players: 10
# Lineup 21:
#
#
# Gerrit Cole
# Frankie Montas
# Ronald Acuna Jr.
# Evan Longoria
# Brandon Belt
# Dansby Swanson
# Marcell Ozuna
# Guillermo Heredia
# Nick Madrigal
# Jonathan Morales
#
#
# Total points: 93.80000000000001
# Cost: $50000
# Number of players: 10
# Lineup 22:
#
#
# Gerrit Cole
# Chris Paddack
# Charlie Blackmon
# Brandon Belt
# Tommy Pham
# Mitch Garver
# Max Kepler
# J.P. Crawford
# Travis Blankenhorn
# Jack Reinheimer
#
#
# Total points: 89.8
# Cost: $49900
# Number of players: 10
# Lineup 23:
#
#
# Gerrit Cole
# Frankie Montas
# Giancarlo Stanton
# Matt Olson
# Evan Longoria
# Amed Rosario
# Luis Robert
# Nick Madrigal
# Zack Granite
# Erik Kratz
#
#
# Total points: 87.9
# Cost: $50000
# Number of players: 10
# Lineup 24:
#
#
# Gerrit Cole
# Alec Mills
# Christian Yelich
# Anthony Rizzo
# Yoan Moncada
# Luis Robert
# Francisco Mejia
# Adam Engel
# Nick Madrigal
# Braden Shewmake
#
#
# Total points: 84.5
# Cost: $50000
# Number of players: 10
# Lineup 25:
#
#
# Gerrit Cole
# Mike Soroka
# Mike Yastrzemski
# Alex Dickerson
# Evan Longoria
# Brandon Belt
# Vimael Machin
# Wilfredo Tovar
# Cody Thomas
# Rocky Gale
#
#
# Total points: 80.10000000000001
# Cost: $49700
# Number of players: 10
# Lineup 26:
#
#
# Jacob deGrom
# Gerrit Cole
# Alex Dickerson
# Brandon Belt
# Nelson Cruz
# Luis Arraez
# Phillip Evans
# Donovan Walton
# Brent Rooker
# Juan Graterol
#
#
# Total points: 79.3
# Cost: $49800
# Number of players: 10
# Lineup 27:
#
#
# Jacob deGrom
# Gerrit Cole
# Alex Dickerson
# Evan Longoria
# Brandon Belt
# Gordon Beckham
# Oneil Cruz
# Ali Sanchez
# Jarrett Parker
# Anthony Garcia
#
#
# Total points: 79.3
# Cost: $49400
# Number of players: 10
# Lineup 28:
#
#
# Jacob deGrom
# Gerrit Cole
# Alex Dickerson
# Evan Longoria
# Brandon Belt
# Gavin Lux
# Owen Miller
# Keibert Ruiz
# DJ Peters
# Luke Raley
#
#
# Total points: 79.2
# Cost: $50000
# Number of players: 10
# Lineup 29:
#
#
# Jacob deGrom
# Gerrit Cole
# Alex Dickerson
# Evan Longoria
# Nelson Cruz
# Greg Garcia
# Taylor Trammell
# Gabriel Arias
# Jake Cronenworth
# Josh Thole
#
#
# Total points: 78.4
# Cost: $49800
# Number of players: 10
# Lineup 30:
#
#
# Jacob deGrom
# Gerrit Cole
# Trevor Story
# Evan Longoria
# Nelson Cruz
# Robel Garcia
# Seby Zavala
# Aaron Whitefield
# Lane Adams
# Zander Wiel
#
#
# Total points: 78.4
# Cost: $50000
# Number of players: 10
# Lineup 31:
#
#
# Jacob deGrom
# Gerrit Cole
# Trevor Story
# Evan Longoria
# Nelson Cruz
# Jason Kipnis
# Brett Phillips
# Nick Heath
# Nick Pratto
# Meibrys Viloria
#
#
# Total points: 78.1
# Cost: $49300
# Number of players: 10
# Lineup 32:
#
#
# Jacob deGrom
# Gerrit Cole
# Alex Dickerson
# Evan Longoria
# Luis Robert
# Sheldon Neuse
# Jorge Mateo
# Andrew Vaughn
# Luis Gonzalez
# Yermin Mercedes
#
#
# Total points: 77.00000000000001
# Cost: $50000
# Number of players: 10
# Lineup 33:
#
#
# Jacob deGrom
# Gerrit Cole
# Alex Dickerson
# Nelson Cruz
# Josh Donaldson
# J.P. Crawford
# Jed Lowrie
# Jake Cave
# Tomas Telis
# P.J. Higgins
#
#
# Total points: 76.39999999999999
# Cost: $49900
# Number of players: 10
# Lineup 34:
#
#
# Gerrit Cole
# Chris Paddack
# Mike Yastrzemski
# Alex Dickerson
# Brandon Belt
# Abiatal Avelino
# Franklin Barreto
# Ke'Bryan Hayes
# Nicky Delmonico
# Joe Hudson
#
#
# Total points: 76.39999999999999
# Cost: $50000
# Number of players: 10
# Lineup 35:
#
#
# Gerrit Cole
# Chris Paddack
# Mike Yastrzemski
# Alex Dickerson
# Brandon Belt
# Zach Green
# Brian Dozier
# Luis Urias
# Patrick Mazeika
# Brennen Davis
#
#
# Total points: 76.2
# Cost: $49800
# Number of players: 10
# Lineup 36:
#
#
# Jacob deGrom
# Gerrit Cole
# Alex Dickerson
# Evan Longoria
# Ronny Rodriguez
# J.P. Crawford
# David Freitas
# Corey Ray
# Keon Broxton
# Austin Barnes
#
#
# Total points: 75.5
# Cost: $50000
# Number of players: 10
# Lineup 37:
#
#
# Gerrit Cole
# Chris Paddack
# Mike Yastrzemski
# Alex Dickerson
# Evan Longoria
# Yolmer Sanchez
# Zack Short
# Logan Morrison
# Mark Mathias
# Oscar Hernandez
#
#
# Total points: 74.9
# Cost: $49800
# Number of players: 10
# Lineup 38:
#
#
# Jacob deGrom
# Gerrit Cole
# Evan Longoria
# Brandon Belt
# Robinson Cano
# Alan Trejo
# Estevan Florial
# Mike Tauchman
# Braden Bishop
# Chris Iannetta
# Total points: 74.7
# Cost: $49100
# Number of players: 10
# Lineup 39:
#
#
# Jacob deGrom
# Walker Buehler
# Alex Dickerson
# Brandon Belt
# Kean Wong
# Nelson Cruz
# Ronald Torreyes
# Deivy Grullon
# Nick Williams
# Alec Bohm
#
#
# Total points: 73.80000000000001
# Cost: $50000
# Number of players: 10
# Lineup 40:
#
#
# Jacob deGrom
# Gerrit Cole
# Evan Longoria
# Brandon Belt
# Melky Cabrera
# Eric Stamets
# Nick Madrigal
# Ryan Cordell
# Jake Fraley
# David Rodriguez
#
#
# Total points: 73.7
# Cost: $49700
# Number of players: 10
# Lineup 41:
#
#
# Gerrit Cole
# Chi Chi Gonzalez
# Trevor Story
# Nolan Arenado
# Keston Hiura
# Nelson Cruz
# Yonder Alonso
# Peter O'Brien
# Alex Jackson
# Scott Schebler
#
#
# Total points: 72.2
# Cost: $49800
# Number of players: 10
# Lineup 42:
#
#
# Gerrit Cole
# Chris Paddack
# Alex Dickerson
# Brandon Belt
# Kris Bryant
# Will Wilson
# Robinson Cano
# Joe McCarthy
# LaMonte Wade Jr.
# Jose Lobaton
#
#
# Total points: 71.80000000000001
# Cost: $49700
# Number of players: 10
# Lineup 43:
#
#
# Jacob deGrom
# Gerrit Cole
# Evan Longoria
# J.P. Crawford
# Robinson Cano
# Daniel Vogelbach
# Tim Lopes
# Yonathan Daza
# A.J. Pollock
# Brian O'Keefe
#
#
# Total points: 71.3
# Cost: $49100
# Number of players: 10
# Lineup 44:
#
#
# Gerrit Cole
# Chris Paddack
# Alex Dickerson
# Evan Longoria
# Tim Anderson
# Robinson Cano
# Gregory Polanco
# Will Craig
# Jason Martin
# Andrew Susac
#
#
# Total points: 70.9
# Cost: $50000
# Number of players: 10
# Lineup 45:
#
#
# Gerrit Cole
# Frankie Montas
# Trevor Story
# Keston Hiura
# Evan Longoria
# Eric Hosmer
# Skye Bolt
# Robbie Grossman
# Cristian Pache
# Carlos Perez
#
#
# Total points: 70.5
# Cost: $49900
# Number of players: 10
# Lineup 46:
#
#
# Gerrit Cole
# Chris Paddack
# Trevor Story
# Evan Longoria
# Darin Ruf
# Jose Siri
# Jaylin Davis
# Robinson Cano
# Clint Frazier
# Cam Gallagher
#
#
# Total points: 70.3
# Cost: $49900
# Number of players: 10
# Lineup 47:
#
#
# Gerrit Cole
# Frankie Montas
# Trevor Story
# Evan Longoria
# Josh Fuentes
# Dustin Fowler
# Robinson Cano
# Luis Barrera
# Mark Zagunis
# Jonah Heim
#
#
# Total points: 67.9
# Cost: $49900
# Number of players: 10
# Lineup 48:
#
#
# Jacob deGrom
# Chris Paddack
# Trevor Story
# Keston Hiura
# Evan Longoria
# Mike Ford
# Adam Haseley
# Mikie Mahtook
# Nick Martini
# Logan O'Hoppe
#
#
# Total points: 41.3
# Cost: $35000
# Number of players: 9
# Lineup 49:
#
#
# Trevor Story
# Evan Longoria
# Brandon Belt
# Robinson Cano
# Nomar Mazara
# Ian Miller
# Josh Naylor
# Kyle Garlick
# Nick Dini
#
#
# Total points: 65.5
# Cost: $47500
# Number of players: 10
# Lineup 50:
#
#
# Gerrit Cole
# Trevor Story
# Evan Longoria
# Brandon Belt
# Adam Duvall
# Mitch Haniger
# Jake Marisnick
# Robinson Cano
# Jarrod Dyson
# Sebastian Rivero
